# %%
import sys
import os
import numpy as np
import cv2
from plantcv import plantcv as pcv

# %%
# Homework Assignment find the area and hue circular mean (color) of the two plants below
# Determine which plant has greater top-down area and add a comment to the end of your notebook
# Documentation for PlantCV can be found here: https://plantcv.readthedocs.io/en/stable/
# once done with the assignment go to File -> Download as -> .html

# %%
#Set global variables
pcv.params.debug = 'plot'                                                           # Plot debug images to the notebook
wt = './examples/shoot-images/3_wt_891.JPG'
vpz = './examples/shoot-images/6_vpz_34_904.JPG'  # Image filename# Image filename

# %%
# Read RGB image and plot it to the notebook
# Inputs:
#    filename = name of image file
wtimg, wtpath, wtfilename = pcv.readimage(wt)

# %%
# Read RGB 2nd image and plot it to the notebook
# Inputs:
#    filename = name of image file
vpzimg, vpzpath, vpzfilename = pcv.readimage(vpz)
